# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import random

# Load the dataset of handwritten text examples
with open('handwritten_text_examples.txt', 'r') as f:
    text = f.read()

# Create a list of unique characters in the dataset
chars = sorted(list(set(text)))

# Prepare the data
maxlen = 40  # Increase sequence length
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# Vectorization
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, chars.index(char)] = 1
    y[i, chars.index(next_chars[i])] = 1

# Build the model
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(maxlen, len(chars))))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(len(chars), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# Train the model
model.fit(X, y, epochs=60, batch_size=64)

# Generate new text
def generate_text(length):
    start_index = random.randint(0, len(text) - maxlen - 1)
    sentence = text[start_index: start_index + maxlen]
    generated = ''
    for i in range(length):
        x = np.zeros((1, maxlen, len(chars)), dtype=bool)
        for t, char in enumerate(sentence):
            x[0, t, chars.index(char)] = 1
        predictions = model.predict(x, verbose=0)[0]
        next_index = np.argmax(predictions)
        next_char = chars[next_index]
        generated += next_char
        sentence = sentence[1:] + next_char
    return generated

# Generate 100 characters of handwritten-like text
print(generate_text(100))
# Out:
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 463ms/step - loss: 3.6877
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - loss: 3.1700
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 3.0450
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - loss: 3.0169
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - loss: 2.9798
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 566ms/step - loss: 3.0058
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - loss: 2.9431
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 2.9818
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 639ms/step - loss: 2.9751
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - loss: 3.0255
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - loss: 2.9879
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 550ms/step - loss: 3.0212
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 416ms/step - loss: 3.0004
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 404ms/step - loss: 2.9735
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 512ms/step - loss: 2.9751
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 402ms/step - loss: 3.0245
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 443ms/step - loss: 2.9685
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - loss: 2.9876
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 405ms/step - loss: 2.8948
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 529ms/step - loss: 2.9313
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 388ms/step - loss: 2.9732
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - loss: 2.9231
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 519ms/step - loss: 2.9341
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 385ms/step - loss: 2.9027
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 393ms/step - loss: 2.9000
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 398ms/step - loss: 2.9337
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 381ms/step - loss: 2.9364
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 595ms/step - loss: 2.8788
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 378ms/step - loss: 2.8908
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 379ms/step - loss: 2.8970
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 483ms/step - loss: 2.8855
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 394ms/step - loss: 2.8461
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 470ms/step - loss: 2.8329
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 534ms/step - loss: 2.8493
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 402ms/step - loss: 2.8008
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 452ms/step - loss: 2.8109
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - loss: 2.8119
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - loss: 2.8575
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - loss: 2.8960
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 382ms/step - loss: 2.8813
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 2.8639
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 505ms/step - loss: 2.8596
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 373ms/step - loss: 2.7922
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 410ms/step - loss: 2.7863
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 378ms/step - loss: 2.7451
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 385ms/step - loss: 2.7634
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 520ms/step - loss: 2.7801
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 380ms/step - loss: 2.7118
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 389ms/step - loss: 2.7023
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 382ms/step - loss: 2.6734
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 392ms/step - loss: 2.6553
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 519ms/step - loss: 2.6637
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 387ms/step - loss: 2.6385
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 378ms/step - loss: 2.7162
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 526ms/step - loss: 2.6535
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 395ms/step - loss: 2.5989
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - loss: 2.7427
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 513ms/step - loss: 2.6982
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 382ms/step - loss: 2.6245
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - loss: 2.5797
# tttttttttttttcc ee ee ee esssttttttt tcee e eee ee sssttatttc e ee e eee e eesssttttttt ceee  eeee
